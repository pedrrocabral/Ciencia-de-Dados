# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import skfuzzy

# %%
# <-- IMPORTAÇÃO DOS DADOS
dados = pd.read_csv(r'C:\Cursos\Formacao_Data_Science\31.Prática em Python\dados\iris.csv')

# %%
# <-- SEPARAÇÃO DOS DADOS
previsores = dados.iloc[:, 0:4].values
classe = dados.iloc[:, 4].values

# %%
# <-- TRANSFORMAÇÃO DOS DADOS CATEGÓRICOS EM NUMÉRICOS
labelencoder = LabelEncoder()
classe = labelencoder.fit_transform(classe)

# %%
r = skfuzzy.cmeans(data=previsores.T, c=3, m=2,
                   error=0.005, maxiter=1000, init=None)

# %%
# <-- VISUALIZAÇÃO DAS PORCENTAGENS PARA CADA INSTÂNCIA
previsoes_porcentagem = r[1]
for i in range(len(previsores)):
    print(previsoes_porcentagem[0][i],
          previsoes_porcentagem[1][i],
          previsoes_porcentagem[2][i])
# Out:
# 0.002500691912344441 0.9963359671922088 0.0011633408954466627
# 0.015898327378675088 0.9769422373805834 0.007159435240741448
# 0.013434707482722621 0.9803022633593864 0.006263029157890936
# 0.0218657484548225 0.9682966610861365 0.009837590459040944
# 0.004131574575671351 0.9939266889680682 0.0019417364562602842
# 0.045805122588389965 0.933115597784367 0.02107927962724309
# 0.014012200132900665 0.9794795057154538 0.006508294151645628
# 0.0002679303392600315 0.9996106310534625 0.00012143860727728884
# 0.04693199695079183 0.9315268085376344 0.02154119451157372
# 0.011273330355500225 0.9836816156255591 0.005045054018940669
# 0.022328344367653033 0.9672028173306054 0.010468838301741583
# 0.005335928019106645 0.9922759858693647 0.0023880861115285665
# 0.019430995044717 0.9717338976914263 0.008835107263856714
# 0.05132330465066667 0.9236704173208117 0.02500627802852158
# 0.07352554560687563 0.8883673010910456 0.03810715330207888
# 0.10573837586660638 0.8392308574276109 0.05503076670578284
# ...

# %%
# <-- AGRUPAMENTO BASIADO NAS PORCENTAGENS
previsoes = previsoes_porcentagem.argmax(axis= 0)
resultados = confusion_matrix(classe, previsoes)
resultados
# Out:
# array([[ 0, 50,  0],
#        [47,  0,  3],
#        [13,  0, 37]], dtype=int64)
